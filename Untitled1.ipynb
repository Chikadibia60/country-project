# %%
# %pip install xgboost
# Out:
# ...
#   Using cached xgboost-3.2.0-py3-none-win_amd64.whl.metadata (2.1 kB)
# ...
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
# ...

# %%
# %pip install xgboost --default-timeout=1000
# Out:
# ...
#   Using cached xgboost-3.2.0-py3-none-win_amd64.whl.metadata (2.1 kB)
# ...
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.5/101.7 MB 1.0 MB/s eta 0:01:41
#    ---------------------------------------- 0.8/101.7 MB 998.1 kB/s eta 0:01:42
#    ---------------------------------------- 1.0/101.7 MB 1.0 MB/s eta 0:01:40
#    ---------------------------------------- 1.0/101.7 MB 1.0 MB/s eta 0:01:40
#    ---------------------------------------- 1.0/101.7 MB 1.0 MB/s eta 0:01:40
#    ---------------------------------------- 1.0/101.7 MB 1.0 MB/s eta 0:01:40
#    ---------------------------------------- 1.0/101.7 MB 1.0 MB/s eta 0:01:40
# ...
